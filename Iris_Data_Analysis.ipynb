# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("iris.csv")
df.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %% [markdown]
# # Data Overview

# %%
df.tail(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.shape
# Out:
# (150, 6)

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# ### Descriptive Statistics

# %%
df["Species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
# Id               150 non-null int64
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.1+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# ##### Scatter plot between saple length and saple width between Species

# %%
sns.relplot(x="SepalLengthCm",y="SepalWidthCm",hue="Species",kind="scatter",data=df)

# %%
sns.catplot(x="SepalLengthCm",y="SepalWidthCm",hue="Species",data=df)

# %%
from scipy import stats
c=np.random.normal(loc=20,size=100,scale=2)
sns.distplot(c)

# %%
sns.boxplot(x="Species",y="SepalLengthCm",data=df)

# %% [markdown]
# ###### The box plot above shows the min and max range of the sepal length for all three species
# below i have tried to find the max and min for all three species. for better comparison.

# %%
setosa=(df[df["Species"]=="Iris-setosa"])
setosa
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# 11  12            4.8           3.4            1.6           0.2  Iris-setosa
# 12  13            4.8           3.0            1.4           0.1  Iris-setosa
# 13  14            4.3           3.0            1.1           0.1  Iris-setosa
# 14  15            5.8           4.0            1.2           0.2  Iris-setosa
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
# 16  17            5.4           3.9            1.3           0.4  Iris-setosa
# 17  18            5.1           3.5            1.4           0.3  Iris-setosa
# 18  19            5.7           3.8            1.7           0.3  Iris-setosa
# 19  20            5.1           3.8            1.5           0.3  Iris-setosa
# 20  21            5.4           3.4            1.7           0.2  Iris-setosa
# 21  22            5.1           3.7            1.5           0.4  Iris-setosa
# 22  23            4.6           3.6            1.0           0.2  Iris-setosa
# 23  24            5.1           3.3            1.7           0.5  Iris-setosa
# 24  25            4.8           3.4            1.9           0.2  Iris-setosa
# 25  26            5.0           3.0            1.6           0.2  Iris-setosa
# 26  27            5.0           3.4            1.6           0.4  Iris-setosa
# 27  28            5.2           3.5            1.5           0.2  Iris-setosa
# 28  29            5.2           3.4            1.4           0.2  Iris-setosa
# 29  30            4.7           3.2            1.6           0.2  Iris-setosa
# 30  31            4.8           3.1            1.6           0.2  Iris-setosa
# 31  32            5.4           3.4            1.5           0.4  Iris-setosa
# 32  33            5.2           4.1            1.5           0.1  Iris-setosa
# 33  34            5.5           4.2            1.4           0.2  Iris-setosa
# 34  35            4.9           3.1            1.5           0.1  Iris-setosa
# 35  36            5.0           3.2            1.2           0.2  Iris-setosa
# 36  37            5.5           3.5            1.3           0.2  Iris-setosa
# 37  38            4.9           3.1            1.5           0.1  Iris-setosa
# 38  39            4.4           3.0            1.3           0.2  Iris-setosa
# 39  40            5.1           3.4            1.5           0.2  Iris-setosa
# 40  41            5.0           3.5            1.3           0.3  Iris-setosa
# 41  42            4.5           2.3            1.3           0.3  Iris-setosa
# 42  43            4.4           3.2            1.3           0.2  Iris-setosa
# 43  44            5.0           3.5            1.6           0.6  Iris-setosa
# 44  45            5.1           3.8            1.9           0.4  Iris-setosa
# 45  46            4.8           3.0            1.4           0.3  Iris-setosa
# 46  47            5.1           3.8            1.6           0.2  Iris-setosa
# 47  48            4.6           3.2            1.4           0.2  Iris-setosa
# 48  49            5.3           3.7            1.5           0.2  Iris-setosa
# 49  50            5.0           3.3            1.4           0.2  Iris-setosa

# %%
versicolor=df[df["Species"]=="Iris-versicolor"]
versicolor
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50   51            7.0           3.2            4.7           1.4
# 51   52            6.4           3.2            4.5           1.5
# 52   53            6.9           3.1            4.9           1.5
# 53   54            5.5           2.3            4.0           1.3
# 54   55            6.5           2.8            4.6           1.5
# 55   56            5.7           2.8            4.5           1.3
# 56   57            6.3           3.3            4.7           1.6
# 57   58            4.9           2.4            3.3           1.0
# 58   59            6.6           2.9            4.6           1.3
# 59   60            5.2           2.7            3.9           1.4
# 60   61            5.0           2.0            3.5           1.0
# 61   62            5.9           3.0            4.2           1.5
# 62   63            6.0           2.2            4.0           1.0
# 63   64            6.1           2.9            4.7           1.4
# 64   65            5.6           2.9            3.6           1.3
# 65   66            6.7           3.1            4.4           1.4
# 66   67            5.6           3.0            4.5           1.5
# 67   68            5.8           2.7            4.1           1.0
# 68   69            6.2           2.2            4.5           1.5
# 69   70            5.6           2.5            3.9           1.1
# 70   71            5.9           3.2            4.8           1.8
# 71   72            6.1           2.8            4.0           1.3
# 72   73            6.3           2.5            4.9           1.5
# 73   74            6.1           2.8            4.7           1.2
# 74   75            6.4           2.9            4.3           1.3
# 75   76            6.6           3.0            4.4           1.4
# 76   77            6.8           2.8            4.8           1.4
# 77   78            6.7           3.0            5.0           1.7
# 78   79            6.0           2.9            4.5           1.5
# 79   80            5.7           2.6            3.5           1.0
# 80   81            5.5           2.4            3.8           1.1
# 81   82            5.5           2.4            3.7           1.0
# 82   83            5.8           2.7            3.9           1.2
# 83   84            6.0           2.7            5.1           1.6
# 84   85            5.4           3.0            4.5           1.5
# 85   86            6.0           3.4            4.5           1.6
# 86   87            6.7           3.1            4.7           1.5
# 87   88            6.3           2.3            4.4           1.3
# 88   89            5.6           3.0            4.1           1.3
# 89   90            5.5           2.5            4.0           1.3
# 90   91            5.5           2.6            4.4           1.2
# 91   92            6.1           3.0            4.6           1.4
# 92   93            5.8           2.6            4.0           1.2
# 93   94            5.0           2.3            3.3           1.0
# 94   95            5.6           2.7            4.2           1.3
# 95   96            5.7           3.0            4.2           1.2
# 96   97            5.7           2.9            4.2           1.3
# 97   98            6.2           2.9            4.3           1.3
# 98   99            5.1           2.5            3.0           1.1
# 99  100            5.7           2.8            4.1           1.3
#
#             Species
# 50  Iris-versicolor
# 51  Iris-versicolor
# 52  Iris-versicolor
# 53  Iris-versicolor
# 54  Iris-versicolor
# 55  Iris-versicolor
# 56  Iris-versicolor
# 57  Iris-versicolor
# 58  Iris-versicolor
# 59  Iris-versicolor
# 60  Iris-versicolor
# 61  Iris-versicolor
# 62  Iris-versicolor
# 63  Iris-versicolor
# 64  Iris-versicolor
# 65  Iris-versicolor
# 66  Iris-versicolor
# 67  Iris-versicolor
# 68  Iris-versicolor
# 69  Iris-versicolor
# 70  Iris-versicolor
# 71  Iris-versicolor
# 72  Iris-versicolor
# 73  Iris-versicolor
# 74  Iris-versicolor
# 75  Iris-versicolor
# 76  Iris-versicolor
# 77  Iris-versicolor
# 78  Iris-versicolor
# 79  Iris-versicolor
# 80  Iris-versicolor
# 81  Iris-versicolor
# 82  Iris-versicolor
# 83  Iris-versicolor
# 84  Iris-versicolor
# 85  Iris-versicolor
# 86  Iris-versicolor
# 87  Iris-versicolor
# 88  Iris-versicolor
# 89  Iris-versicolor
# 90  Iris-versicolor
# 91  Iris-versicolor
# 92  Iris-versicolor
# 93  Iris-versicolor
# 94  Iris-versicolor
# 95  Iris-versicolor
# 96  Iris-versicolor
# 97  Iris-versicolor
# 98  Iris-versicolor
# 99  Iris-versicolor

# %%
virginica=df[df["Species"]=="Iris-virginica"]
virginica
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 106  107            4.9           2.5            4.5           1.7
# 107  108            7.3           2.9            6.3           1.8
# 108  109            6.7           2.5            5.8           1.8
# 109  110            7.2           3.6            6.1           2.5
# 110  111            6.5           3.2            5.1           2.0
# 111  112            6.4           2.7            5.3           1.9
# 112  113            6.8           3.0            5.5           2.1
# 113  114            5.7           2.5            5.0           2.0
# 114  115            5.8           2.8            5.1           2.4
# 115  116            6.4           3.2            5.3           2.3
# 116  117            6.5           3.0            5.5           1.8
# 117  118            7.7           3.8            6.7           2.2
# 118  119            7.7           2.6            6.9           2.3
# 119  120            6.0           2.2            5.0           1.5
# 120  121            6.9           3.2            5.7           2.3
# 121  122            5.6           2.8            4.9           2.0
# 122  123            7.7           2.8            6.7           2.0
# 123  124            6.3           2.7            4.9           1.8
# 124  125            6.7           3.3            5.7           2.1
# 125  126            7.2           3.2            6.0           1.8
# 126  127            6.2           2.8            4.8           1.8
# 127  128            6.1           3.0            4.9           1.8
# 128  129            6.4           2.8            5.6           2.1
# 129  130            7.2           3.0            5.8           1.6
# 130  131            7.4           2.8            6.1           1.9
# 131  132            7.9           3.8            6.4           2.0
# 132  133            6.4           2.8            5.6           2.2
# 133  134            6.3           2.8            5.1           1.5
# 134  135            6.1           2.6            5.6           1.4
# 135  136            7.7           3.0            6.1           2.3
# 136  137            6.3           3.4            5.6           2.4
# 137  138            6.4           3.1            5.5           1.8
# 138  139            6.0           3.0            4.8           1.8
# 139  140            6.9           3.1            5.4           2.1
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 100  Iris-virginica
# 101  Iris-virginica
# 102  Iris-virginica
# 103  Iris-virginica
# 104  Iris-virginica
# 105  Iris-virginica
# 106  Iris-virginica
# 107  Iris-virginica
# 108  Iris-virginica
# 109  Iris-virginica
# 110  Iris-virginica
# 111  Iris-virginica
# 112  Iris-virginica
# 113  Iris-virginica
# 114  Iris-virginica
# 115  Iris-virginica
# 116  Iris-virginica
# 117  Iris-virginica
# 118  Iris-virginica
# 119  Iris-virginica
# 120  Iris-virginica
# 121  Iris-virginica
# 122  Iris-virginica
# 123  Iris-virginica
# 124  Iris-virginica
# 125  Iris-virginica
# 126  Iris-virginica
# 127  Iris-virginica
# 128  Iris-virginica
# 129  Iris-virginica
# 130  Iris-virginica
# 131  Iris-virginica
# 132  Iris-virginica
# 133  Iris-virginica
# 134  Iris-virginica
# 135  Iris-virginica
# 136  Iris-virginica
# 137  Iris-virginica
# 138  Iris-virginica
# 139  Iris-virginica
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
print("SepalLengthCm range min to max for iris-setosa : ",min(setosa["SepalLengthCm"]),"to",max(setosa["SepalLengthCm"]))
print("SepalWidthCm range min to max for iris-setosa : ",min(setosa["SepalWidthCm"]),"to",max(setosa["SepalWidthCm"]))
print("PetalLengthCm range min to max for iris-setosa : ",min(setosa["PetalLengthCm"]),"to",max(setosa["PetalLengthCm"]))
print("PetalWidthCm range min to max for iris-setosa : ",min(setosa["PetalWidthCm"]),"to",max(setosa["PetalWidthCm"]))
# Out:
# SepalLengthCm range min to max for iris-setosa :  4.3 to 5.8
# SepalWidthCm range min to max for iris-setosa :  2.3 to 4.4
# PetalLengthCm range min to max for iris-setosa :  1.0 to 1.9
# PetalWidthCm range min to max for iris-setosa :  0.1 to 0.6

# %%
print("SepalLengthCm range min to max for iris-versicolor : ",min(versicolor["SepalLengthCm"]),"to",max(versicolor["SepalLengthCm"]))
print("SepalWidthCm range min to max for iris-versicolor : ",min(versicolor["SepalWidthCm"]),"to",max(versicolor["SepalWidthCm"]))
print("PetalLengthCm range min to max for iris-versicolor : ",min(versicolor["PetalLengthCm"]),"to",max(versicolor["PetalLengthCm"]))
print("PetalWidthCm range min to max for iris-versicolor : ",min(versicolor["PetalWidthCm"]),"to",max(versicolor["PetalWidthCm"]))
# Out:
# SepalLengthCm range min to max for iris-versicolor :  4.9 to 7.0
# SepalWidthCm range min to max for iris-versicolor :  2.0 to 3.4
# PetalLengthCm range min to max for iris-versicolor :  3.0 to 5.1
# PetalWidthCm range min to max for iris-versicolor :  1.0 to 1.8

# %%
print("SepalLengthCm range min to max for iris-virginica : ",min(virginica["SepalLengthCm"]),"to",max(virginica["SepalLengthCm"]))
print("SepalWidthCm range min to max for iris-virginica : ",min(virginica["SepalWidthCm"]),"to",max(virginica["SepalWidthCm"]))
print("PetalLengthCm range min to max for iris-virginica : ",min(virginica["PetalLengthCm"]),"to",max(virginica["PetalLengthCm"]))
print("PetalWidthCm range min to max for iris-virginica : ",min(virginica["PetalWidthCm"]),"to",max(virginica["PetalWidthCm"]))
# Out:
# SepalLengthCm range min to max for iris-virginica :  4.9 to 7.9
# SepalWidthCm range min to max for iris-virginica :  2.2 to 3.8
# PetalLengthCm range min to max for iris-virginica :  4.5 to 6.9
# PetalWidthCm range min to max for iris-virginica :  1.4 to 2.5

# %%
data={"Species":["Iris-setosa","iris-versicolor","iris-virginica"],"sepalLengthRange":["4.3-5.8","4.9-7.0","4.9-7.9"],"SepalWidthRange":["2.3-4.4","2.0-3.4","2.2-3.8"],"PetalLengthRange":["1.0-1.9","3.0-5.1","4.5-6.9"],"PetalWidthRange":["0.1-0.6","1.0-1.8","1.4-2.5"]}
nd=pd.DataFrame(data)
nd
# Out:
#            Species sepalLengthRange SepalWidthRange PetalLengthRange  \
# 0      Iris-setosa          4.3-5.8         2.3-4.4          1.0-1.9
# 1  iris-versicolor          4.9-7.0         2.0-3.4          3.0-5.1
# 2   iris-virginica          4.9-7.9         2.2-3.8          4.5-6.9
#
#   PetalWidthRange
# 0         0.1-0.6
# 1         1.0-1.8
# 2         1.4-2.5

# %% [markdown]
# ###### above dataframe shows that iris-setosa has less Sepal length, Petal length and Petal Width as compared to other 2 species

# %%
a=sns.FacetGrid(df,col="Species")
a.map(sns.distplot,"SepalLengthCm")

# %%
sns.pairplot(df,hue="Species",size=3)
# Out:
# C:\Users\gurdit\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# From above distributions and scatter graphs it is clear that setosa can be differentiated amongst the species how ever virginica and versicolor , the petal width ,length and sepal width, length can not differention the two.

# %% [markdown]
# # Collecting data by Web Scraping
#
# The data of Covid-19 cases in India is uploaded and updated everyday on www.mohfw.gov.in and the below code is written to scrape and extract the the information and is stored in a csv file. The csv file will contain all the data for that particular day. The Stored csv files will then be used for analysis and visualization of the spread of Covid-19 in India.Since different csv files will be stored everyday after executing the program, the spread can be tracked.

# %%
import csv
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs
import requests
from datetime import datetime as dt

# %%
link="https://www.mohfw.gov.in/"
req=requests.get(link)
data=bs(req.content,"html.parser")

# %%
data
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport">
# <title>Ministry of Health and Family Welfare | GOI RSS</title>
# <link href="assets/images/favicon.ico" rel="shortcut icon"/>
# <link href="https://maxcdn.bootstrapcdn.com/bootstrap/3.4.1/css/bootstrap.min.css" rel="stylesheet"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.4.1/jquery.min.js"></script>
# <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.4.1/js/bootstrap.min.js"></script>
# <link href="assets/css/font-awesome.min.css" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Poppins:300,400,500,600,700" rel="stylesheet"/>
# <link href="assets/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="assets/css/style.css" rel="stylesheet" type="text/css"/>
# <!--[if lt IE 9]>
# 		<script type="text/javascript" src="assets/js/html5.js"></script>
# ...

# %%
table=data.find_all('thead')[-1]

# %%
table
# Out:
# <thead class="thead-dark">
# <tr bgcolor="#f8f8f8">
# <th align="left" width="47"><strong>S. No.</strong></th>
# <th align="left" width="83"><strong>Name of State / UT</strong></th>
# <th align="left" width="91"><strong>Total Confirmed cases (Indian National)</strong></th>
# <th align="left" width="90"><strong>Total Confirmed cases ( Foreign National )</strong></th>
# <th align="left" width="83"><strong>Cured/<br/>Discharged/Migrated</strong></th>
# <th align="left" width="83"><strong>Death</strong></th>
# </tr>
# </thead>

# %%
type(table)
# Out:
# bs4.element.Tag

# %%
head=table.find_all("tr")
tbody=data.find_all("tbody")[-1]

# %%
head
# Out:
# [<tr bgcolor="#f8f8f8">
#  <th align="left" width="47"><strong>S. No.</strong></th>
#  <th align="left" width="83"><strong>Name of State / UT</strong></th>
#  <th align="left" width="91"><strong>Total Confirmed cases (Indian National)</strong></th>
#  <th align="left" width="90"><strong>Total Confirmed cases ( Foreign National )</strong></th>
#  <th align="left" width="83"><strong>Cured/<br/>Discharged/Migrated</strong></th>
#  <th align="left" width="83"><strong>Death</strong></th>
#  </tr>]

# %%
tbody
# Out:
# <tbody>
# <tr>
# <td align="'centre" width="47">1</td>
# <td align="'centre" valign="bottom" width="83">Andhra Pradesh</td>
# <td align="'centre" valign="bottom" width="91">9</td>
# <td align="'centre" valign="top" width="90">0</td>
# <td align="'centre" valign="top" width="83">1</td>
# <td align="'centre" valign="top" width="83">0</td>
# </tr>
# <tr>
# <td align="'centre" width="47">2</td>
# <td align="'centre" valign="bottom" width="83">Bihar</td>
# <td align="'centre" valign="bottom" width="91">4</td>
# <td align="'centre" valign="top" width="90">0</td>
# <td align="'centre" valign="top" width="83">0</td>
# <td align="'centre" valign="top" width="83">1</td>
# </tr>
# <tr>
# <td align="'centre" width="47">3</td>
# <td align="'centre" valign="bottom" width="83">Chhattisgarh</td>
# <td align="'centre" valign="bottom" width="91">1</td>
# <td align="'centre" valign="top" width="90">0</td>
# <td align="'centre" valign="top" width="83">0</td>
# ...

# %%
body=tbody.find_all("tr")

# %%
body
# Out:
# [<tr>
#  <td align="'centre" width="47">1</td>
#  <td align="'centre" valign="bottom" width="83">Andhra Pradesh</td>
#  <td align="'centre" valign="bottom" width="91">9</td>
#  <td align="'centre" valign="top" width="90">0</td>
#  <td align="'centre" valign="top" width="83">1</td>
#  <td align="'centre" valign="top" width="83">0</td>
#  </tr>, <tr>
#  <td align="'centre" width="47">2</td>
#  <td align="'centre" valign="bottom" width="83">Bihar</td>
#  <td align="'centre" valign="bottom" width="91">4</td>
#  <td align="'centre" valign="top" width="90">0</td>
#  <td align="'centre" valign="top" width="83">0</td>
#  <td align="'centre" valign="top" width="83">1</td>
#  </tr>, <tr>
#  <td align="'centre" width="47">3</td>
#  <td align="'centre" valign="bottom" width="83">Chhattisgarh</td>
#  <td align="'centre" valign="bottom" width="91">1</td>
#  <td align="'centre" valign="top" width="90">0</td>
#  <td align="'centre" valign="top" width="83">0</td>
# ...

# %%
h_rows=[]
b_rows=[]
for tr in head:
    td=tr.find_all(['th','td'])
    row=[i.text for i in td]
    h_rows.append(row)
print(h_rows)
# Out:
# [['S. No.', 'Name of State / UT', 'Total Confirmed cases (Indian National)', 'Total Confirmed cases ( Foreign National )', 'Cured/Discharged/Migrated', 'Death']]

# %%
for tr in body:
    td=tr.find_all(['th','td'])
    row=[i.text for i in td]
    b_rows.append(row)
print(b_rows)
# Out:
# [['1', 'Andhra Pradesh', '9', '0', '1', '0'], ['2', 'Bihar', '4', '0', '0', '1'], ['3', 'Chhattisgarh', '1', '0', '0', '0'], ['4', 'Delhi', '30', '1', '6', '1'], ['5', 'Gujarat', '37', '1', '0', '1'], ['6', 'Haryana', '14', '14', '11', '0'], ['7', 'Himachal Pradesh', '3', '0', '0', '1'], ['8', 'Karnataka', '41', '0', '3', '1'], ['9', 'Kerala', '101', '8', '4', '0'], ['10', 'Madhya Pradesh', '14', '0', '0', '0'], ['11', 'Maharashtra', '125', '3', '1', '3'], ['12', 'Manipur', '1', '0', '0', '0'], ['13', 'Mizoram', '1', '0', '0', '0'], ['14', 'Odisha', '2', '0', '0', '0'], ['15', 'Puducherry', '1', '0', '0', '0'], ['16', 'Punjab', '29', '0', '0', '1'], ['17', 'Rajasthan', '34', '2', '3', '0'], ['18', 'Tamil Nadu', '16', '2', '1', '0'], ['19', 'Telengana', '25', '10', '1', '0'], ['20', 'Chandigarh', '7', '0', '0', '0'], ['21', 'Jammu and Kashmir', '7', '0', '1', '0'], ['22', 'Ladakh', '13', '0', '0', '0'], ['23', 'Uttar Pradesh', '36', '1', '11', '0'], ['24', 'Uttarakhand', '3', '1', '0'
# ...

# %%
df=pd.DataFrame(b_rows[:len(b_rows)-1],columns=h_rows[0])

# %%
df
# Out:
#    S. No. Name of State / UT Total Confirmed cases (Indian National)  \
# 0       1     Andhra Pradesh                                       9
# 1       2              Bihar                                       4
# 2       3       Chhattisgarh                                       1
# 3       4              Delhi                                      30
# 4       5            Gujarat                                      37
# 5       6            Haryana                                      14
# 6       7   Himachal Pradesh                                       3
# 7       8          Karnataka                                      41
# 8       9             Kerala                                     101
# 9      10     Madhya Pradesh                                      14
# 10     11        Maharashtra                                     125
# 11     12            Manipur                                       1
# 12     13            Mizoram                                       1
# ...

# %%
df.drop("S. No.",axis=1,inplace=True)

# %%
df
# Out:
#    Name of State / UT Total Confirmed cases (Indian National)  \
# 0      Andhra Pradesh                                       9
# 1               Bihar                                       4
# 2        Chhattisgarh                                       1
# 3               Delhi                                      30
# 4             Gujarat                                      37
# 5             Haryana                                      14
# 6    Himachal Pradesh                                       3
# 7           Karnataka                                      41
# 8              Kerala                                     101
# 9      Madhya Pradesh                                      14
# 10        Maharashtra                                     125
# 11            Manipur                                       1
# 12            Mizoram                                       1
# 13             Odisha                                       2
# ...

# %%
df1=df.copy()

# %%
df2=df.copy()

# %%
df2["Date"]=dtn.strftime("%m/%d/%y")

# %%
x=pd.to_datetime(df2["Date"],format='%m/%d/%y')
df2["Date"]=pd.to_datetime(df2["Date"],format='%m/%d/%y')

# %%
x
# Out:
# 0    2020-03-25
# 1    2020-03-25
# 2    2020-03-25
# 3    2020-03-25
# 4    2020-03-25
# 5    2020-03-25
# 6    2020-03-25
# 7    2020-03-25
# 8    2020-03-25
# 9    2020-03-25
# 10   2020-03-25
# 11   2020-03-25
# 12   2020-03-25
# 13   2020-03-25
# 14   2020-03-25
# 15   2020-03-25
# 16   2020-03-25
# 17   2020-03-25
# 18   2020-03-25
# 19   2020-03-25
# 20   2020-03-25
# 21   2020-03-25
# 22   2020-03-25
# 23   2020-03-25
# 24   2020-03-25
# Name: Date, dtype: datetime64[ns]

# %%
dtn=dt.now()
df1["Date"]=dtn.strftime('%m/%d/%y')
df1["Date"]=pd.to_datetime(df1["Date"],format="%m/%d/%y")

# %%
df1
# Out:
#    Name of State / UT Total Confirmed cases (Indian National)  \
# 0      Andhra Pradesh                                       9
# 1               Bihar                                       4
# 2        Chhattisgarh                                       1
# 3               Delhi                                      30
# 4             Gujarat                                      37
# 5             Haryana                                      14
# 6    Himachal Pradesh                                       3
# 7           Karnataka                                      41
# 8              Kerala                                     101
# 9      Madhya Pradesh                                      14
# 10        Maharashtra                                     125
# 11            Manipur                                       1
# 12            Mizoram                                       1
# 13             Odisha                                       2
# ...

# %%
latitude = {'Delhi':28.7041,
           'Haryana':29.0588,
           'Kerala':10.8505,
           'Rajasthan':27.0238,
           'Telengana':18.1124,
           'Uttar Pradesh':26.8467,
           'Ladakh':34.2996,
           'Tamil Nadu':11.1271,
           'Jammu and Kashmir':33.7782,
           'Punjab':31.1471,
           'Karnataka':15.3173,
           'Maharashtra':19.7515,
           'Andhra Pradesh':15.9129, 
           'Odisha':20.9517, 
           'Uttarakhand':30.0668, 
           'West Bengal':22.9868, 
           'Puducherry': 11.9416, 
           'Chandigarh': 30.7333, 
           'Chhattisgarh':21.2787, 
           'Gujarat': 22.2587, 
           'Himachal Pradesh': 31.1048, 
           'Madhya Pradesh': 22.9734, 
           'Bihar': 25.0961, 
           'Manipur':24.6637, 
           'Mizoram':23.1645}

longitude = {'Delhi':77.1025,
            'Haryana':76.0856,
            'Kerala':76.2711,
            'Rajasthan':74.2179,
            'Telengana':79.0193,
            'Uttar Pradesh':80.9462,
            'Ladakh':78.2932,
            'Tamil Nadu':78.6569,
            'Jammu and Kashmir':76.5762,
            'Punjab':75.3412,
            'Karnataka':75.7139,
            'Maharashtra':75.7139,
            'Andhra Pradesh':79.7400, 
            'Odisha':85.0985, 
            'Uttarakhand':79.0193, 
            'West Bengal':87.8550, 
            'Puducherry': 79.8083, 
            'Chandigarh': 76.7794, 
            'Chhattisgarh':81.8661, 
            'Gujarat': 71.1924, 
            'Himachal Pradesh': 77.1734, 
            'Madhya Pradesh': 78.6569, 
            'Bihar': 85.3131, 
            'Manipur':93.9063, 
            'Mizoram':92.9376}

# %%
df2["Latitude"]=df2["Name of State / UT"].map(latitude)

# %%
df2.head()
# Out:
#   Name of State / UT Total Confirmed cases (Indian National)  \
# 0     Andhra Pradesh                                       9
# 1              Bihar                                       4
# 2       Chhattisgarh                                       1
# 3              Delhi                                      30
# 4            Gujarat                                      37
#
#   Total Confirmed cases ( Foreign National ) Cured/Discharged/Migrated Death  \
# 0                                          0                         1     0
# 1                                          0                         0     1
# 2                                          0                         0     0
# 3                                          1                         6     1
# 4                                          1                         0     1
#
#         Date  Latitude
# 0 2020-03-25   15.9129
# 1 2020-03-25   25.0961
# 2 2020-03-25   21.2787
# 3 2020-03-25   28.7041
# ...

# %%
df2["Longitude"]=df2["Name of State / UT"].map(longitude)

# %%
df2.head()
# Out:
#   Name of State / UT Total Confirmed cases (Indian National)  \
# 0     Andhra Pradesh                                       9
# 1              Bihar                                       4
# 2       Chhattisgarh                                       1
# 3              Delhi                                      30
# 4            Gujarat                                      37
#
#   Total Confirmed cases ( Foreign National ) Cured/Discharged/Migrated Death  \
# 0                                          0                         1     0
# 1                                          0                         0     1
# 2                                          0                         0     0
# 3                                          1                         6     1
# 4                                          1                         0     1
#
#         Date  Latitude  Longitude
# 0 2020-03-25   15.9129    79.7400
# 1 2020-03-25   25.0961    85.3131
# ...

# %%
df1.isnull().sum()
# Out:
# Name of State / UT                            0
# Total Confirmed cases (Indian National)       0
# Total Confirmed cases ( Foreign National )    0
# Cured/Discharged/Migrated                     0
# Death                                         0
# Date                                          0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# Name of State / UT                            0
# Total Confirmed cases (Indian National)       0
# Total Confirmed cases ( Foreign National )    0
# Cured/Discharged/Migrated                     0
# Death                                         0
# Date                                          0
# Latitude                                      0
# Longitude                                     0
# dtype: int64

# %%
filename=dtn.strftime("%y_%m_%d")+'.csv'

pd.DataFrame(df2).to_csv("C:\\Users\\gurdit\\Desktop\\DataScience\\github\\Corona\\Corona_india\\perday_data\\"+filename,index=False)
